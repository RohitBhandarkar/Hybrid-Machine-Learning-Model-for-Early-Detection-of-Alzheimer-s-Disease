# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.experimental import enable_iterative_imputer

# %%
raw_data = pd.read_csv('/home/rohitb/projects/ml/Project/assets/OASIS-1/oasis_cross-sectional-5708aa0a98d82080.csv')
# raw_data=raw_data.drop(['ID','M/F','Hand','Educ','SES','MMSE','Delay'],axis=1)
id_col = raw_data[['ID']]
raw_data=raw_data.drop(['ID','Delay'],axis=1)
raw_data.head()
# Out:
#   M/F Hand  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0   F    R   74   2.0  3.0  29.0  0.0  1344  0.743  1.306
# 1   F    R   55   4.0  1.0  29.0  0.0  1147  0.810  1.531
# 2   F    R   73   4.0  3.0  27.0  0.5  1454  0.708  1.207
# 3   M    R   28   NaN  NaN   NaN  NaN  1588  0.803  1.105
# 4   M    R   18   NaN  NaN   NaN  NaN  1737  0.848  1.010

# %%
completed_data = raw_data.dropna()
testing_data = raw_data.dropna()
indices = np.random.choice(testing_data.index, size=int(0.4*len(testing_data['CDR'])), replace=False)

# %%
# Create label encoder objects
le_gender = LabelEncoder()
le_hand = LabelEncoder()

# Encode M/F column
testing_data['M/F'] = le_gender.fit_transform(testing_data['M/F'])
# Encode M/F column for completed_data
completed_data['M/F'] = le_gender.fit_transform(completed_data['M/F'])

# Encode Hand column 
testing_data['Hand'] = le_hand.fit_transform(testing_data['Hand'])
# Encode Hand column for completed_data
completed_data['Hand'] = le_hand.fit_transform(completed_data['Hand'])
# Out:
# /tmp/ipykernel_8180/1447372608.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data['M/F'] = le_gender.fit_transform(testing_data['M/F'])
# /tmp/ipykernel_8180/1447372608.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completed_data['M/F'] = le_gender.fit_transform(completed_data['M/F'])
# /tmp/ipykernel_8180/1447372608.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data['Hand'] = le_hand.fit_transform(testing_data['Hand'])
# /tmp/ipykernel_8180/1447372608.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completed_data['Hand'] = le_hand.fit_transform(completed_data['Hand'])

# %% [markdown]
#  Here's a quick breakdown of which might be more correlated:
#
# - Age: Highly likely to be correlated with CDR, as older age is a known risk factor for cognitive decline and dementia.
# - eTIV (Estimated Total Intracranial Volume): Could have a weaker correlation, as brain volume is indirectly related to age and dementia, but not a direct measure of cognitive decline.
# - nWBV (Normalized Whole Brain Volume): More relevant than eTIV, as it reflects the proportion of the brain remaining after accounting for atrophy, which is a hallmark of dementia.
# - ASF (Atlas Scaling Factor): Might show some indirect correlation with brain size, but its relevance to cognitive decline could be lower.
# - M/F (Gender): There are known differences in how dementia progresses between males and females, so it might have some correlation.
# - Hand (Handedness): Likely to have little correlation with CDR.

# %% [markdown]
# Filling the CDR values with data imputation methods. In this case Multivariate Imputation by Chained-Equations (MICE) is used.

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %% [markdown]
# There will be a comparision done between:
# - MICE with Linear Regression
# - MICE with Random Forrest Regression
# - MICE with Support Vector Regression
#
# And the best one will be chosen

# %% [markdown]
# # MICE with Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
testing_data.loc[indices,'CDR'] = np.nan
testing_data
# Out:
#      M/F  Hand  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0      0     0   74   2.0  3.0  29.0  NaN  1344  0.743  1.306
# 1      0     0   55   4.0  1.0  29.0  NaN  1147  0.810  1.531
# 2      0     0   73   4.0  3.0  27.0  0.5  1454  0.708  1.207
# 8      1     0   74   5.0  2.0  30.0  NaN  1636  0.689  1.073
# 9      0     0   52   3.0  2.0  30.0  NaN  1321  0.827  1.329
# ..   ...   ...  ...   ...  ...   ...  ...   ...    ...    ...
# 411    0     0   70   1.0  4.0  29.0  NaN  1295  0.748  1.355
# 412    0     0   73   3.0  2.0  23.0  NaN  1536  0.730  1.142
# 413    0     0   61   2.0  4.0  28.0  NaN  1354  0.825  1.297
# 414    1     0   61   5.0  2.0  30.0  NaN  1637  0.780  1.072
# 415    0     0   62   3.0  3.0  26.0  0.0  1372  0.766  1.279
#
# [216 rows x 10 columns]

# %%
lr = LinearRegression()
imp = IterativeImputer(estimator=lr, verbose=2, max_iter=5, imputation_order='roman')

# %%
ImputedData = imp.fit_transform(testing_data)
# Out:
# [IterativeImputer] Completing matrix with shape (216, 10)
# [IterativeImputer] Ending imputation round 1/5, elapsed time 0.04
# [IterativeImputer] Change: 1.0230866146152326, scaled tolerance: 1.992
# [IterativeImputer] Early stopping criterion reached.

# %%
Imputed_data = pd.DataFrame(ImputedData)
Imputed_data.columns = raw_data.columns
Imputed_data.head()
# Out:
#    M/F  Hand   Age  Educ  SES  MMSE       CDR    eTIV   nWBV    ASF
# 0  0.0   0.0  74.0   2.0  3.0  29.0  0.127248  1344.0  0.743  1.306
# 1  0.0   0.0  55.0   4.0  1.0  29.0 -0.133830  1147.0  0.810  1.531
# 2  0.0   0.0  73.0   4.0  3.0  27.0  0.500000  1454.0  0.708  1.207
# 3  1.0   0.0  74.0   5.0  2.0  30.0  0.166272  1636.0  0.689  1.073
# 4  0.0   0.0  52.0   3.0  2.0  30.0 -0.054497  1321.0  0.827  1.329

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse_lr = mean_squared_error(Imputed_data, completed_data)
print(f'Mean Squared Error (MSE): {mse_lr}')

mae_lr = mean_absolute_error(Imputed_data, completed_data)
print(f'Mean Absolute Error (MAE): {mae_lr}')

r_squared_lr = r2_score(Imputed_data, completed_data)
print(f'Coefficient of Determination (R-squared): {r_squared_lr}')
# Out:
# Mean Squared Error (MSE): 0.002021270418865502
# Mean Absolute Error (MAE): 0.007024790426572043
# Coefficient of Determination (R-squared): 0.9833223975199591

# %% [markdown]
# # MICE with Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
testing_data.loc[indices,'CDR'] = np.nan
testing_data
# Out:
#      M/F  Hand  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0      0     0   74   2.0  3.0  29.0  NaN  1344  0.743  1.306
# 1      0     0   55   4.0  1.0  29.0  NaN  1147  0.810  1.531
# 2      0     0   73   4.0  3.0  27.0  0.5  1454  0.708  1.207
# 8      1     0   74   5.0  2.0  30.0  NaN  1636  0.689  1.073
# 9      0     0   52   3.0  2.0  30.0  NaN  1321  0.827  1.329
# ..   ...   ...  ...   ...  ...   ...  ...   ...    ...    ...
# 411    0     0   70   1.0  4.0  29.0  NaN  1295  0.748  1.355
# 412    0     0   73   3.0  2.0  23.0  NaN  1536  0.730  1.142
# 413    0     0   61   2.0  4.0  28.0  NaN  1354  0.825  1.297
# 414    1     0   61   5.0  2.0  30.0  NaN  1637  0.780  1.072
# 415    0     0   62   3.0  3.0  26.0  0.0  1372  0.766  1.279
#
# [216 rows x 10 columns]

# %%
rf = RandomForestRegressor(n_estimators=100)
imp = IterativeImputer(estimator=rf, verbose=2, max_iter=5, imputation_order='roman')

# %%
ImputedData = imp.fit_transform(testing_data)
# Out:
# [IterativeImputer] Completing matrix with shape (216, 10)
# [IterativeImputer] Ending imputation round 1/5, elapsed time 2.84
# [IterativeImputer] Change: 1.056923076923077, scaled tolerance: 1.992
# [IterativeImputer] Early stopping criterion reached.

# %%
Imputed_data = pd.DataFrame(ImputedData)
Imputed_data.columns = raw_data.columns
Imputed_data.head()
# Out:
#    M/F  Hand   Age  Educ  SES  MMSE    CDR    eTIV   nWBV    ASF
# 0  0.0   0.0  74.0   2.0  3.0  29.0  0.055  1344.0  0.743  1.306
# 1  0.0   0.0  55.0   4.0  1.0  29.0  0.030  1147.0  0.810  1.531
# 2  0.0   0.0  73.0   4.0  3.0  27.0  0.500  1454.0  0.708  1.207
# 3  1.0   0.0  74.0   5.0  2.0  30.0  0.200  1636.0  0.689  1.073
# 4  0.0   0.0  52.0   3.0  2.0  30.0  0.000  1321.0  0.827  1.329

# %%
mse_rf = mean_squared_error(Imputed_data, completed_data)
print(f'Mean Squared Error (MSE): {mse_rf}')

mae_rf = mean_absolute_error(Imputed_data, completed_data)
print(f'Mean Absolute Error (MAE): {mae_rf}')

r_squared_rf = r2_score(Imputed_data, completed_data)
print(f'Coefficient of Determination (R-squared): {r_squared_rf}')
# Out:
# Mean Squared Error (MSE): 0.0020376388888888883
# Mean Absolute Error (MAE): 0.006509259259259259
# Coefficient of Determination (R-squared): 0.9839076327197696

# %% [markdown]
# # MICE with Support Vector Regression

# %%
from sklearn.svm import SVR

# %%
testing_data.loc[indices,'CDR'] = np.nan
testing_data
# Out:
#      M/F  Hand  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0      0     0   74   2.0  3.0  29.0  NaN  1344  0.743  1.306
# 1      0     0   55   4.0  1.0  29.0  NaN  1147  0.810  1.531
# 2      0     0   73   4.0  3.0  27.0  0.5  1454  0.708  1.207
# 8      1     0   74   5.0  2.0  30.0  NaN  1636  0.689  1.073
# 9      0     0   52   3.0  2.0  30.0  NaN  1321  0.827  1.329
# ..   ...   ...  ...   ...  ...   ...  ...   ...    ...    ...
# 411    0     0   70   1.0  4.0  29.0  NaN  1295  0.748  1.355
# 412    0     0   73   3.0  2.0  23.0  NaN  1536  0.730  1.142
# 413    0     0   61   2.0  4.0  28.0  NaN  1354  0.825  1.297
# 414    1     0   61   5.0  2.0  30.0  NaN  1637  0.780  1.072
# 415    0     0   62   3.0  3.0  26.0  0.0  1372  0.766  1.279
#
# [216 rows x 10 columns]

# %%
svm = SVR()
imp = IterativeImputer(estimator=svm, verbose=2, max_iter=5, imputation_order='roman')

# %%
ImputedData = imp.fit_transform(testing_data)
# Out:
# [IterativeImputer] Completing matrix with shape (216, 10)
# [IterativeImputer] Ending imputation round 1/5, elapsed time 0.03
# [IterativeImputer] Change: 0.17501513064231444, scaled tolerance: 1.992
# [IterativeImputer] Early stopping criterion reached.

# %%
Imputed_data = pd.DataFrame(ImputedData)
Imputed_data.columns = raw_data.columns
Imputed_data.head()
# Out:
#    M/F  Hand   Age  Educ  SES  MMSE       CDR    eTIV   nWBV    ASF
# 0  0.0   0.0  74.0   2.0  3.0  29.0  0.100252  1344.0  0.743  1.306
# 1  0.0   0.0  55.0   4.0  1.0  29.0  0.098062  1147.0  0.810  1.531
# 2  0.0   0.0  73.0   4.0  3.0  27.0  0.500000  1454.0  0.708  1.207
# 3  1.0   0.0  74.0   5.0  2.0  30.0  0.101950  1636.0  0.689  1.073
# 4  0.0   0.0  52.0   3.0  2.0  30.0  0.098758  1321.0  0.827  1.329

# %%
mse_svr = mean_squared_error(Imputed_data, completed_data)
print(f'Mean Squared Error (MSE): {mse_svr}')

mae_svr = mean_absolute_error(Imputed_data, completed_data)
print(f'Mean Absolute Error (MAE): {mae_svr}')

r_squared_svr = r2_score(Imputed_data, completed_data)
print(f'Coefficient of Determination (R-squared): {r_squared_svr}')
# Out:
# Mean Squared Error (MSE): 0.006279180439264285
# Mean Absolute Error (MAE): 0.010716759054748498
# Coefficient of Determination (R-squared): 0.9356747299176996

# %% [markdown]
# # Comparision between different imputation models

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'Model': ['MICE + LR', 'MICE + RF', 'MICE + SVR'],
    'MSE': [mse_lr,mse_rf,mse_svr],  # Replace with your actual MSE values
    'MAE': [mae_lr,mae_rf,mae_svr],  # Replace with your actual MAE values
    'R²': [r_squared_lr,r_squared_rf,r_squared_svr]    # Replace with your actual R² values
}

# Create DataFrame
df = pd.DataFrame(data)

# Set the plot style
sns.set(style="whitegrid")

# Create a figure and axes for the subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Bar plot for MSE
sns.barplot(x='Model', y='MSE', data=df, ax=axes[0])
axes[0].set_title('MSE Comparison')
axes[0].set_ylabel('MSE Value')
axes[0].set_xlabel('Models')

# Bar plot for MAE
sns.barplot(x='Model', y='MAE', data=df, ax=axes[1])
axes[1].set_title('MAE Comparison')
axes[1].set_ylabel('MAE Value')
axes[1].set_xlabel('Models')

# Bar plot for R²
sns.barplot(x='Model', y='R²', data=df, ax=axes[2])
axes[2].set_title('R² Comparison')
axes[2].set_ylabel('R² Value')
axes[2].set_xlabel('Models')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# Thus MICE+RF seems to give the best result of data imputation and thus will be used to fill the NAN values

# %%
raw_data = pd.read_csv('/home/rohitb/projects/ml/Project/assets/OASIS-1/oasis_cross-sectional-5708aa0a98d82080.csv')
to_impute_data=raw_data.drop(['ID','Delay'],axis=1)
id_col = raw_data[['ID']]
# Create label encoders for M/F and Hand columns
le_gender = LabelEncoder()
le_hand = LabelEncoder()

# Fit and transform the M/F column
to_impute_data['M/F'] = le_gender.fit_transform(to_impute_data['M/F'])

# Fit and transform the Hand column 
to_impute_data['Hand'] = le_hand.fit_transform(to_impute_data['Hand'])


to_impute_data
# Out:
#      M/F  Hand  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0      0     0   74   2.0  3.0  29.0  0.0  1344  0.743  1.306
# 1      0     0   55   4.0  1.0  29.0  0.0  1147  0.810  1.531
# 2      0     0   73   4.0  3.0  27.0  0.5  1454  0.708  1.207
# 3      1     0   28   NaN  NaN   NaN  NaN  1588  0.803  1.105
# 4      1     0   18   NaN  NaN   NaN  NaN  1737  0.848  1.010
# ..   ...   ...  ...   ...  ...   ...  ...   ...    ...    ...
# 431    1     0   20   NaN  NaN   NaN  NaN  1469  0.847  1.195
# 432    1     0   22   NaN  NaN   NaN  NaN  1684  0.790  1.042
# 433    1     0   22   NaN  NaN   NaN  NaN  1580  0.856  1.111
# 434    0     0   20   NaN  NaN   NaN  NaN  1262  0.861  1.390
# 435    0     0   26   NaN  NaN   NaN  NaN  1283  0.834  1.368
#
# [436 rows x 10 columns]

# %%
rf = RandomForestRegressor(n_estimators=100)
imp = IterativeImputer(estimator=rf, verbose=2, max_iter=5, imputation_order='roman')

# %%
ImputedData = imp.fit_transform(to_impute_data)
# Out:
# [IterativeImputer] Completing matrix with shape (436, 10)
# [IterativeImputer] Ending imputation round 1/5, elapsed time 7.04
# [IterativeImputer] Change: 7.325740740740739, scaled tolerance: 1.992
# [IterativeImputer] Ending imputation round 2/5, elapsed time 13.59
# [IterativeImputer] Change: 2.825000000000003, scaled tolerance: 1.992
# [IterativeImputer] Ending imputation round 3/5, elapsed time 18.59
# [IterativeImputer] Change: 3.7549999999999994, scaled tolerance: 1.992
# [IterativeImputer] Ending imputation round 4/5, elapsed time 23.78
# [IterativeImputer] Change: 2.285000000000002, scaled tolerance: 1.992
# [IterativeImputer] Ending imputation round 5/5, elapsed time 29.88
# [IterativeImputer] Change: 2.3999999999999995, scaled tolerance: 1.992
# /usr/lib/python3/dist-packages/sklearn/impute/_iterative.py:801: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
Imputed_data = pd.DataFrame(ImputedData)
Imputed_data.columns = to_impute_data.columns
Imputed_data = pd.concat([id_col, Imputed_data], axis=1)
Imputed_data.head()
# Out:
#               ID  M/F  Hand   Age  Educ   SES   MMSE    CDR    eTIV   nWBV  \
# 0  OAS1_0001_MR1  0.0   0.0  74.0  2.00  3.00  29.00  0.000  1344.0  0.743
# 1  OAS1_0002_MR1  0.0   0.0  55.0  4.00  1.00  29.00  0.000  1147.0  0.810
# 2  OAS1_0003_MR1  0.0   0.0  73.0  4.00  3.00  27.00  0.500  1454.0  0.708
# 3  OAS1_0004_MR1  1.0   0.0  28.0  3.82  1.47  22.06  0.595  1588.0  0.803
# 4  OAS1_0005_MR1  1.0   0.0  18.0  3.88  1.56  22.07  0.585  1737.0  0.848
#
#      ASF
# 0  1.306
# 1  1.531
# 2  1.207
# 3  1.105
# 4  1.010

# %%
def round_to_half(value):
    return round(value * 2) / 2

Imputed_data['CDR'] = Imputed_data['CDR'].apply(round_to_half)

# %%
Imputed_data.head()
# Out:
#               ID  M/F  Hand   Age  Educ   SES   MMSE  CDR    eTIV   nWBV  \
# 0  OAS1_0001_MR1  0.0   0.0  74.0  2.00  3.00  29.00  0.0  1344.0  0.743
# 1  OAS1_0002_MR1  0.0   0.0  55.0  4.00  1.00  29.00  0.0  1147.0  0.810
# 2  OAS1_0003_MR1  0.0   0.0  73.0  4.00  3.00  27.00  0.5  1454.0  0.708
# 3  OAS1_0004_MR1  1.0   0.0  28.0  3.82  1.47  22.06  0.5  1588.0  0.803
# 4  OAS1_0005_MR1  1.0   0.0  18.0  3.88  1.56  22.07  0.5  1737.0  0.848
#
#      ASF
# 0  1.306
# 1  1.531
# 2  1.207
# 3  1.105
# 4  1.010

# %%
Imputed_data.to_csv('/home/rohitb/projects/ml/Project/data/oasis_cleaned.csv', index=False)

# %% [markdown]
# # Splitting OASIS 2 for sequential data analysis and hybrid model

# %%
csv_path = '/home/rohitb/projects/ml/Project/data/oasis_longitudinal_demographics.csv'
data = pd.read_csv(csv_path)
data.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
# Get unique subjects and their labels
subject_groups = data.groupby('Subject ID')['Group'].first()

# Split subjects by diagnosis group to maintain distribution
nondemented = subject_groups[subject_groups == 'Nondemented'].index
demented = subject_groups[subject_groups == 'Demented'].index 
converted = subject_groups[subject_groups == 'Converted'].index

# Calculate split sizes for each group (80-20 split)
n_nondemented = int(len(nondemented) * 0.8)
n_demented = int(len(demented) * 0.8)
n_converted = int(len(converted) * 0.8)

# Randomly sample subjects from each group
np.random.seed(42)
sequential_nondemented = np.random.choice(nondemented, n_nondemented, replace=False)
sequential_demented = np.random.choice(demented, n_demented, replace=False)
sequential_converted = np.random.choice(converted, n_converted, replace=False)

# Create masks for splitting
sequential_subjects = np.concatenate([sequential_nondemented, sequential_demented, sequential_converted])
sequential_mask = data['Subject ID'].isin(sequential_subjects)

# Split the data
sequential_data = data[sequential_mask].copy()
hybrid_data = data[~sequential_mask].copy()

# Verify distributions
print("Sequential Data Distribution:")
print(sequential_data.groupby('Group').size())
print("\nHybrid Data Distribution:") 
print(hybrid_data.groupby('Group').size())

# Save the splits
sequential_data.to_csv('/home/rohitb/projects/ml/Project/data/oasis_longitudinal_sequential.csv', index=False)
hybrid_data.to_csv('/home/rohitb/projects/ml/Project/data/oasis_longitudinal_hybrid.csv', index=False)
# Out:
# Sequential Data Distribution:
# Group
# Converted       30
# Demented       116
# Nondemented    151
# dtype: int64
#
# Hybrid Data Distribution:
# Group
# Converted       7
# Demented       30
# Nondemented    39
# dtype: int64
